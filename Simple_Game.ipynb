# %%
import random
#Layout: 3 rooms green door, yellow door locked, red door locked
# Green room fight slime (1-5) damage per hit
# Yellow Room trap room? Can hurt traps? (5-20) damage each
  #Red key is at the end of the hall player sees it
  #But also sees traps
  #(Future Update) Percentages to spot traps
  #Percentages to break traps with your weapons so it doesn't hurt you
  #One trap will kill you no matter what if you get hit?
    #Arrow trap (Low chance to damage(5-10))
    #Pitfall trap (Not hidden at all) (ladder to get out too) (Medium chance to take damage(15))
    #Boulder Trap (Red Square that says do not step on it) (Player chance to die or not)
    #Once you grab the key the whole room catches on fire
# Red Room fight flying monster (10-20)
#     “The bone spines hooked into the creature’s hide and pulled it to the ground making a loud thud sound.

#LATER UPDATE:
    # Make Life and Revive Life into a variable so i can easily change everything later.
        #Example just say {player_instance.life} / {player_instance.life_start}

#Objective: Find the way out exit is past the red door room
#Obstacles: Traps, Enemies
#Player: Life, Sword, yellow key, red key, exit key


#Has all the players deaths, keys, doors, etc, variables
class player: #blue print
  def __init__(self): #runs when the player is created
    self.life = 100 #Current life
    self.life_start = 100 #Starting Health
    self.revive = False #Plot Armor: Narrator Revives you back to 333 life in fight
    self.revive_life = 333 #Current life
    self.revive_life_start = 333 #Starting Health
    self.has_sword = False
    self.has_whip = False
    self.has_rubberducky = False
    self.has_yellow_key = False
    self.has_red_key = False
    self.has_exit_key = False
    self.start_room = 0
    self.try_yellow_locked_door = True
    self.try_red_locked_door = True
    self.death_script = False
    self.victory_run = False

#Players weapons damage
class weapons:
  def __init__(self):
    self.sword_level = 0
    self.damage = 0

  def sword_damage(self):
    #returns random damage between 3 to 7
    return random.randint(3,7)
  def sword_crit_damage(self):
    #returns random critical hit damage between (5 to 7)x2
    return random.randint(5,7) * 2

  def bonewhip_damage(self):
    #returns random damage between 5 to 9
    return random.randint(5,9)
  def bonewhip_crit_damage(self):
    #returns random critical hit damage between (6 to 9)x2
    return random.randint(6,9) * 2

#Contains slime monsters health, attack_turns variables, and random damage
class slime:
  def __init__(self):
    self.attack_turns = 0
    self.life = 15
  def damage(self):
    #Slime does random damage from 1 to 5
    return random.randint(1,5)

#Trap variables on if traps are active and damage
class trap:
  def __init__(self):
    self.pitfall_trap = True #First time there
    self.pitfall_fell = 0 #First try jumping back
    self.arrow_trap_broken = False
  def arrow_trap_damage(self):
    return random.randint(5,20)

#Boss monster's life, damage, and turn order
class Snuggles:
  def __init__(self):
    self.attack_turns = 0
    self.life = 666
  def damage(self):
    #temp random damage
    return random.randint(15,50)

#Currently not in Use
#Planning to add in attack for when monster is in the air or ground
  #def damage_air(self):
    #More damage because of more faster/powerful sweeping attack
    #return random.randint(10,30)
  #def damage_ground(self):
    #Swiping attacks, 15 damage for tail strike
    #return random.randint(10,15)

#Shows what rooms have been entered
class rooms:
  def __init__(self):
    self.start_room = False
    self.green_room = False
    self.yellow_room = False
    self.yellow_door_locked = 0
    self.red_room = False
    self.left_yellow_room = False

#Has all the death endings in here
class death:
  #death from arrow trap
  def trap_arrow_death(self):
    print(f"YOU HAVE DIED!")
    print()
    print(f"""Narrator: "{name}, I guess the arrows were too much for you" """)
    print()
    print(f"""Evil Person: "HAHAHAHA! I knew you would die with your stupid name. {name}, that's
    almost slightly better than Narrator HAHAHAHA!" """)
    exit()
    #death from pitfall trap (NOTE: Very hard to get this death)
  def trap_pitfall_death(self):
    print(f"YOU HAVE DIED!")
    print()
    print(f"""Narrator: "{name}, how did you die it wasn't even covered up?!" """)
    print()
    print(f"""Evil Person: "HAHAHAHA! I knew you would die with your stupid name. {name}, that's
    almost slightly better than Narrator HAHAHAHA!""")
    exit()
    #going back to starting room Death failing to climb up from pitfall trap (NOTE:Very rare to get this death)
  def trap_pitfall_fire_death():
    print("""Narrator: "You are stuck there until you die... I'd guess about 2 days since, the heat made you
    sweat a lot. That's a rough way to die..." """)
    print()
    print(f"YOU HAVE DIED!")
    print()
    print(f"""Evil Person: "HAHAHAHA! I knew you would die with your stupid name, I just didn't expect you to die like that,
    {name}, that's almost slightly better than Narrator HAHAHAHA!""")
    player_instance.death_script = True
    exit()
    #Death from bouder (NOTE: Very easy to get this death)
  def trap_the_boulder_death(self):
    print(f"YOU HAVE DIED!")
    print()
    print(f"""Narrator: "...wow... {name}, just went splat" """)
    print()
    print(f"""Evil Person: "HAHAHAHA! That was hilarous, {name}, looked so scared. I knew you would die with your
    stupid name. {name}, that's almost slightly better than Narrator HAHAHAHA!""")
    player_instance.death_script = True
    exit()
 #Death from Snuggles after getting plot armor
  def plot_armor_death_from_Snuggles(self):
    print()
    print("YOU HAVE DIED")
    print()
    print("Narrator enters bursting through the ceiling and sees your dead body being snuggled by Mr. Snuggles")
    print()
    print("""Narrator: "I was too late? The plot armor wasn't enough" """)
    print()
    print("Evil Person flies down with his wings from the hole Narrator left")
    print()
    print("""Evil Person: "HAHAHA, good job Mr. Snuggles now lets kill Narrator together" """)
    print()
    print("Narrator put up a good fight landing a few blows, but he didn't stand a chance in a two on one fight")
    print()
    print("Defeat")
    exit()
  #Victory? user died but Narrator won
  def plot_armor_death_from_Evil_Person(self):
    print()
    print("YOU HAVE DIED")
    print()
    print("""Narrator screams out in rage "YOU WILL PAY FOR THAT" """)
    print()
    print(f"""Evil Person: "{name}, DESERVED IT FOR KILLING MR. SNUGGLES" """)
    print()
    print("They fought dodging and exchanging blows for hours. Eventually Narrator landed a piercing fatal blow")
    print()
    print("""With blood pouring of his mouth Evil Person he laughs "How did you win? I had everything planned out,
    with lots of back up plans, and back up plans, for those back ups." """)
    print()
    print("""The bloodied Narrated breaths out "I found your plans and access codes" """)
    print()
    print("""Evil Person: "HAHAHAHAHA, I didn't make a plan for that..." """)
    print()
    print("""Evil Person takes his final breath leaving behind a devilish grin with eyes full of pride" """)
    print()
    print(f"""Narrator: "Sorry {name}... I wasn't strong enough to save you. Rest well, may we meet again" """)
    print()
    print("Victory?")
    exit()
    return True





#Allows access to classes by calling, Example: player_instance.life()
player_instance = player()
rooms_instance = rooms()
weapons_instance = weapons()
slime_instance = slime()
trap_instance = trap()
Snuggles_instance = Snuggles()
death_instance = death()

#Dodge slime monster
  #Has 3 random chances
    #Dodge: no damage done
    #Parital Dodge - some random damage
    #Failed - full damage taken
def dodge_slime():
  result = random.choices(
      ["Dodge", "Partial Dodge", "Failed"],
      weights = [40, 30, 30]   )[0]
  if result == "Dodge":
    print()
    print("Narrator: You dodged and the green ball of goo went flying past you!")
    slime_instance.attack_turns = 3
  if result == "Partial Dodge":
    damage = slime_instance.damage() /2
    player_instance.life -= damage
    print()
    print(f"Narrator: You dodged but the slime grazed you as it flew by dealing {damage} damage!")
    print(f"Heath: {player_instance.life} /100")
    slime_instance.attack_turns = 2
  if result == "Failed":
    damage = slime_instance.damage()
    player_instance.life -= damage
    print()
    print(f"Narrator: You fell trying to dodge and the slime attacked dealing {damage} damage!")
    print(f"Heath: {player_instance.life} /100")

#Dodge flying monster (AKA SNUGGLES)
  #Has 3 random chances
    #Dodge: no damage done
    #Parital Dodge - some random damage
    #Failed - full damage taken
  def dodge_flying_monster():
    result = random.choices(
      ["Dodge", "Partial Dodge", "Failed"],
      weights = [20, 40, 40]   )[0]
    if result == "Dodge":
      print()
      print("Narrator: You dodged the flying monstroity's attack!")
      flying_monster_instance.attack_turns = 3
    if result == "Partial Dodge":
      damage = flying_monster_instance.damage() /2
      player_instance.life -= damage
      print()
      print(f"Narrator: You dodged but the beast grazed you with its claws as it flew by dealing {damage} damage!")
      print(f"Heath: {player_instance.life} /100")
      flying_monster_instance.attack_turns = 2
    if result == "Failed":
      damage = flying_monster_instance.damage()
      player_instance.life -= damage
      print()
      print(f"Narrator: You fell trying to dodge and the monster sinked his claws into you dealing {damage} damage!")
      print(f"Heath: {player_instance.life} /100")


#Sword attack function
  #Has 4 random chances
    #Hit - random normal attack damage
    #Critical Hit - random normal attack damage times 2
    #Miss - did no damage
    #Hurt Self - random damage to self
def attack_sword():
  #if weapons.sword_level = 0 then 1 etc then can increase hit chance each time while lowering miss/hurt self
  result = random.choices(
      ["Hit", "Critical Hit", "Miss", "Hurt Self"],
      weights = [60, 10, 20, 10] )[0]
  if result == "Hit":
    #if died once
    if player_instance.revive == True:
      #Plot Armor bonus damage
      weapons_instance.damage = (weapons_instance.sword_damage() * 10)
      print()
      print(f"Narrator: You did {weapons_instance.damage} damage!")

      #didn't die at all yet
    if player_instance.revive == False:
      weapons_instance.damage = weapons_instance.sword_damage()
      print()
      print(f"Narrator: You did {weapons_instance.damage} damage!")

  if result == "Critical Hit":
    #if died once
    if player_instance.revive == True:
      #Plot Armor bonus damage
      weapons_instance.damage = (weapons_instance.sword_crit_damage() * 10)
      print()
      print(f"Narrator: You got a critical hit! The sword pierced into it dealing {weapons_instance.damage} damage! ")

      #didn't die at all yet
    if player_instance.revive == False:
      weapons_instance.damage = weapons_instance.sword_crit_damage()
      print()
      print(f"Narrator: You got a critical hit! Your bone sword pierced into it dealing {weapons_instance.damage} damage! ")

  if result == "Miss":
    print()
    print(f"Narrator: You swung and missed... ")
    weapons_instance.damage = 0

  if result == "Hurt Self":
    weapons_instance.damage = weapons_instance.sword_damage()
    player_instance.life -= weapons_instance.damage
    print()
    print(f"Narrator: You swung, missed, and hit yourself dealing {weapons_instance.damage} damage to yourself")
    #if died once
    if player_instance.revive == True:
      #damage done to extra life
      print(f"Heath: {player_instance.revive_life} /{player_instance.revive_life_start}")

    #damage done to first life
    if player_instance.revive == False:
      print(f"Heath: {player_instance.life} /{player_instance.life_start}")
    weapons_instance.damage = 0


#Sword attack function
  #Has 4 random chances
    #Hit - random normal attack damage
    #Critical Hit - random normal attack damage times 2
    #Miss - did no damage
    #Hurt Self - random damage to self
def attack_bone_whip():
  result = random.choices(
      ["Hit","Critical Hit", "Miss", "Hurt Self"],
      weights = [40, 10, 30, 20] )[0]
  if result == "Hit":
    #if once died
    if player_instance.revive == True:
      #Plot Armor bonus damage
      weapons_instance.damage = (weapons_instance.bonewhip_damage() * 10)
      print()
      print(f"Narrator: You did {weapons_instance.damage} damage!")

    #didn't die at all yet
    if player_instance.revive == False:
      weapons_instance.damage = weapons_instance.bonewhip_damage()
      print()
      print(f"Narrator: You did {weapons_instance.damage} damage!")

  if result == "Critical Hit":
    #if died once
    if player_instance.revive == True:
      #Plot Armor bonus damage
      weapons_instance.damage = (weapons_instance.bonewhip_crit_damage() * 10)
      print()
      print(f"Narrator: You got a critical hit! The sword pierced into it dealing {weapons_instance.damage} damage! ")

    #didn't die at all yet
    if player_instance.revive == False:
      weapons_instance.damage = weapons_instance.bonewhip_crit_damage()
      print()
      print(f"Narrator: You got a critical hit! Your bone sword pierced into it dealing {weapons_instance.damage} damage! ")

  if result == "Miss":
    print()
    print(f"Narrator: You whipped and missed...")
    weapons_instance.damage = 0

  if result == "Hurt Self":
    weapons_instance.damage = weapons_instance.bonewhip_damage()
    player_instance.life -= weapons_instance.damage
    print()
    print(f"Narrator: You lashed, missed, and hit yourself dealing {weapons_instance.damage} damage to yourself")
    #if died once
    if player_instance.revive == True:
      #damage done to extra life
      print(f"Heath: {player_instance.revive_life} /{player_instance.revive_life_start}")

    #damage done to first life
    if player_instance.revive == False:
      print(f"Heath: {player_instance.life} /{player_instance.life_start}")
    weapons_instance.damage = 0


#Fight Slime with sword
def fight_slime_sword():
  #if slime is alive
  if slime_instance.life > 0:
    print()
    print("""Narrator: "Quick Tip, after a successful dodge the slime can't attack you for two turns. You got this!" """)
    print()
    while True:
      choice = str(input("""What do you do?
      Option 1: Attack With Bone Sword
      Option 2: Dodge
      Option 3: Run
      """))
      #if player types in any of these do this:
      if choice.lower() in("1", "Attack With Bone Sword", "Bone Sword", "Sword", "Attack"):
        attack_sword()
        slime_instance.life -= weapons_instance.damage
        #If slime monster has zero life(dead) do this:
        if slime_instance.life <= 0:
          print(""" Narrator: "You defeated the slime monster" """)
          print()
          print(""" Evil Person: "How did you beat him, you must have cheated!" """)
          print()
          print(f""" Narrator: "You watched the fight, {name} didn't use any tricks." """)
          print()
          print(f""" Evil Person: "You are still a cheater, and I'll make sure you will die in the next room""")
          print()
          print(""" Narrator: "... Anyways, you noticed that on the ground where the slime monster died, lay
          a yellow key. You walked over to it and picked it up. You wonder to yourself "I could probably use this on
          the yellow door."
          """)
          print()
          break
          #If slime has zero or less than zero turns left it can attack again
        if slime_instance.attack_turns <= 0:
            damage = slime_instance.damage()
            player_instance.life -= damage
            print(f"Narrator: The slime attacked back and did {damage} ")
            print(f"Heath: {player_instance.life} /100")
            print()
        #If slime has more than zero turns left it can't attack
        if slime_instance.attack_turns > 0:
          slime_instance.attack_turns -= 1
          if slime_instance.attack_turns == 1:
            print(f"""Narrator: "The slime is dizzy from the attack, {slime_instance.attack_turns} turn left""")
          else:
            print(f"""Narrator: "The slime is dizzy from the attack, {slime_instance.attack_turns} turns left""")
          print()
        continue
      #dodge slime monster
      if choice.lower() in ("2", "Dodge"):
        dodge_slime()
        print()
        if slime_instance.attack_turns > 0:
          slime_instance.attack_turns -= 1
          if slime_instance.attack_turns == 1:
            print(f"""Narrator: "The slime is dizzy from the attack, {slime_instance.attack_turns} turn left""")
          else:
            print(f"""Narrator: "The slime is dizzy from the attack, {slime_instance.attack_turns} turns left""")
          print()
        continue
      #running does nothing just there for humor, but it does set monster attack turns to 0 so it can attack right away
      if choice.lower() in ("3", "Run"):
        print("""Narrator: You ran around trying to find a way out. But you remember that the green door
        is locked so you have no where to run to. The slime is slowly inching closer to you. Also, because you ran
        the slime is ready to attack.
        """)
        slime_instance.attack_turns = 0
        continue

#fight slime monster with whip
def fight_slime_monster_bone_whip():
  #if slime alive
  if slime_instance.life > 0:
    print()
    print("""Narrator: Quick Tip, after a successful dodge the slime can't attack you for two turns. You got this!""")
    print()
    while True:
      choice = str(input("""What do you do?
      Option 1: Attack With Bone Whip
      Option 2: Dodge
      Option 3: Run
      """))
      #if player types in any of these do this:
      if choice.lower() in("1", "Attack With Bone Whip", "Whip", "Bone Whip", "Attack"):
        attack_bone_whip()
        slime_instance.life -= weapons_instance.damage
        #If slime monster has zero life(dead) do this:
        if slime_instance.life <= 0:
          print(""" Narrator: "You defeated the slime monster" """)
          print()
          print(""" Evil Person: "How did you beat him, you must have cheated!" """)
          print()
          print(f""" Narrator: "You watched the fight, {name} didn't use any tricks." """)
          print()
          print(f""" Evil Person: "You are still a cheater, and I'll make sure you will die in the next room""")
          print()
          print(""" Narrator: "... Anyways, you noticed that on the ground where the slime monster died, lay
          a yellow key. You walked over to it and picked it up. You wonder to yourself "I could probably use this on
          the yellow door."
          """)
          print()
          break
        #If slime has zero or less than zero turns left it can attack again
        if slime_instance.attack_turns <= 0:
            damage = slime_instance.damage()
            player_instance.life -= damage
            print(f"Narrator: The slime attacked back and did {damage} ")
            print(f"Heath: {player_instance.life} /100")
            print()
          #If slime has more than zero turns left it can't attack
        if slime_instance.attack_turns > 0:
          slime_instance.attack_turns -= 1
          if slime_instance.attack_turns == 1:
            print(f"""Narrator: "The slime is dizzy from the attack, {slime_instance.attack_turns} turn left""")
          else:
            print(f"""Narrator: "The slime is dizzy from the attack, {slime_instance.attack_turns} turns left""")
          print()
        continue
      #dodge slime monster
      if choice.lower() in ("2", "Dodge"):
        dodge_slime()
        print()
        if slime_instance.attack_turns > 0:
          slime_instance.attack_turns -= 1
          if slime_instance.attack_turns == 1:
            print(f"""Narrator: "The slime is dizzy from the attack, {slime_instance.attack_turns} turn left""")
          else:
            print(f"""Narrator: "The slime is dizzy from the attack, {slime_instance.attack_turns} turns left""")
          print()
        continue
      #running does nothing just there for humor, but it does set monster attack turns to 0 so it can attack right away
      if choice.lower() in ("3", "Run"):
        print("""Narrator: You ran around trying to find a way out. But you remember that the green door
            is locked so you have no where to run to. The slime is slowly inching closer to you. Also, because you ran
            the slime is ready to attack.
            """)
        slime_instance.attack_turns = 0
        continue

#Trap Function Section
# Yellow Room trap room? Can hurt traps? (5-20) damage each
  #Red key is at the end of the hall player sees it
  #But also sees traps
  #(Future Update) Percentages to spot traps
  #Percentages to break traps with your weapons so it doesn't hurt you
  #One trap will kill you no matter what if you get hit?
    #Arrow trap (Low chance to damage(5-10))
    #Pitfall trap (Not hidden at all) (ladder to get out too) (Medium chance to take damage(15))
    #Boulder Trap (Red Square that says do not step on it) (Player chance to die or not)
    #Once you grab the key the whole room catches on fire

#Arrow Trap
  #3 options
    #Run through - random chance to succeed, fail take damage
    #Try to disable it - always breaks the trap but can take lots of damage
    #Whack it until it breaks - Always succeeds but takes some damage
def arrow_trap():
  if trap_instance.arrow_trap_broken == True:
    print()
    print("""Narrator: "Good thing you took care of the arrow trap, now you can run right through it" """)
    print()
  if trap_instance.arrow_trap_broken == False:
    while True:
      choice = str(input("""What do you do?
      Option 1: Run Through
      Option 2: Try To Disable It
      Option 3: Whack It Until It Breaks
      """))
      #Random chance to take damage or make it unharmed
      if choice.lower() in("1, Run Through, Run"):
        print("""Narrator: "You try to run through the trap" """)
        result = random.choices( #choices for 4 sets, with 4 chances
          ["Dodged","Grazed", "Hit", "Tripped And Hit"],
          weights = [30, 20, 30, 20] )[0]
        if result == "Dodged": #Trap not broken
          print()
          print("""Narrator: "You somehow ran through all the arrows dodging and weaving past each one """)
          print()
          trap_instance.arrow_trap_broken == False #Trap not broken
          break
        if result == "Grazed":
          print()
          print("""Narrator: You ran through dodging a few arrows but as you were getting out of the arrow volleys an
          arrow hit you in the knee dealing 5 damage. Some how you can still walk.""")
          print()
          player_instance.life -= 5
          print(f"Heath: {player_instance.life} /100")
          print()
          if player_instance.life <=0:
            death_instance.trap_arrow_death()
          break
        if result == "Hit":
          print()
          print("""Narrator: "You ran through, getting hit by multiple arrows. You seem to be a magnetic for arrows.
          You took 10 damage. """)
          print()
          player_instance.life -= 10
          print()
          print(f"Heath: {player_instance.life} /100")
          print()
          if player_instance.life <=0:
            death_instance.trap_arrow_death()
          break
        if result == "Tripped And Hit":
          print()
          print("""Narrator: "You tried running through, but you tripped into a volley of arrows getting hit by a dozen arrows. You took 20 damage.""")
          print()
          player_instance.life -= 20
          print()
          print(f"Heath: {player_instance.life} /100")
          print()
          if player_instance.life <=0:
            death_instance.trap_arrow_death()
          break
      #Always disables the trap but can take lots of damage
      if choice.lower() in("2, Try To Disable It, Disable"):
        print("""Narrator: "You try to disable it using your wits" """)
        results = random.choices(
            ["Smart","Average","Dummy"],
            weights = [30, 50, 20] )[0]
        if results == "Smart":
          print()
          print("""Narrator: "You must be pretty smart, because you disabled the trap easily" """)
          print()
          trap_instance.arrow_trap_broken = True
          if player_instance.life <=0:
            death_instance.trap_arrow_death()
          break
        if results == "Average":
          print()
          print("""Narrator: "Your wits helped you disabled the trap, but as you were disabling it an arrow hit you. You took 5 damage" """)
          print()
          player_instance.life -= 5
          print(f"Heath: {player_instance.life} /100")
          print()
          trap_instance.arrow_trap_broken = True
          if player_instance.life <=0:
            death_instance.trap_arrow_death()
          break
        if results == "Dummy":
          print()
          print("""'KaBOOM' """)
          print()
          print("""Narrator: "..." """)
          print()
          print("""Narrator: "How did you make it explode?! That's crazy" """)
          print()
          print("""Evil Person: "The trap isn't even made of anything that could make it explode, HAHAHAHA""")
          print()
          print("""Narrator: "Well um, you took 25 damage, how did you survive?" """)
          print()
          player_instance.life -=25
          print(f"Heath:{player_instance.life} /100 ")
          print()
          trap_instance.arrow_trap_broken = True
          if player_instance.life <=0: #if life is 0 or less play death
            death_instance.trap_arrow_death()
          break
      #Always breaks the trap and always does 5 damage to player  (NOTE: Best path to take the least amount of damage)
      if choice.lower() in("3, Whack It Until It Breaks, Whack It, Break It"):
        #if player has sword play this text
        if player_instance.has_sword == True:
          print("""Narrator: "You whacked it with your sword" """)
          print("""Narrator: "You whacked it with your sword" """)
          print("""Narrator: "You whacked it with your sword" """)
          print()
          print("""Narrator: "You sliced it right in half, but shards of wood and arrows hit you dealing 5 damage" """)
          print()
          player_instance.life -= 5
          print(f"Heath: {player_instance.life} /100")
          print()
          trap_instance.arrow_trap_broken = True
          if player_instance.life <=0:
            death_instance.trap_arrow_death()
          break
        #if player has whip play this text
        if player_instance.has_whip == True:
          print("""Narrator: "You whacked it with your whip" """)
          print("""Narrator: "You whacked it with your whip" """)
          print("""Narrator: "You whacked it with your whip" """)
          print()
          print("""Narrator: "The bone whip's sharp edges sliced it right in half, but shards of wood and arrows hit you dealing 5 damage" """)
          print()
          player_instance.life -= 5
          print(f"Heath: {player_instance.life} /100")
          print()
          trap_instance.arrow_trap_broken = True
          if player_instance.life <=0:
            death_instance.trap_arrow_death()
          break

#Pitfall trap
  #2 options
    #Run and jump - chance to take damage on fail
    #Jump down - takes reduced damage
def pitfall_trap():
  #Second time at pitfall trap
    #can't jump down since ladder is on your side
  if trap_instance.pitfall_trap == False:
    while True:
      choice = str(input("""What do you do?
      Option 1: Run and jump
      """))
      #Run and jump 3 chances, 2 of them hurt player
      if choice.lower() in("1, Run and Jump, Jump"):
        results = random.choices(
            ["Jumped", "Barely", "Fell"],
            weights = [50, 30, 20]) [0]
        if results == "Jumped":
          print()
          print("""Narrator: "You ran and jumped accross safely making it over" """)
          print()
          break
        if results == "Barely":
          print()
          print("""Narrator: "You ran and jumped accross, but your jump was a little short. You slammed your
          stomach into the ledge. Then you pulled yourself up while trying to ignore the pain. You took 3 damage" """)
          print()
          player_instance.life -= 3
          print(f"Heath: {player_instance.life} /100")
          print()
          if player_instance.life <= 0:
            death_instance.trap_pitfall_death()
          break
        if results == "Fell":
          if trap_instance.pitfall_fell == 2:
            print()
            print("""Narrator: "COME ON YOU MISSED AGAIN! Oh no,  the fire it's on the ladder. You can't escape now.
            The fire is spreading down the ladder soon you won't be able to handle the heat. Stay down so you don't breath
            in the smoke.""")
            print()
            return death_instance.trap_pitfall_fire_death()
          if trap_instance.pitfall_fell == 1:
            print()
            print("""Narrator: "You missed and took 15 damage now RUN! HURRY CLIMB UP!.""")
            print()
            player_instance.life -= 15
            print(f"Heath: {player_instance.life} /100 ")
            print()
            if player_instance.life <= 0:
              death_instance.trap_pitfall_death()
            trap_instance.pitfall_fell = 2
          if trap_instance.pitfall_fell == 0:
            print()
            print("""Narrator: "You ran and jumped but you missed and hit your head on the wall, and fell. Taking 15 damage.
            You then used the ladder on the wall to climb up. Go faster! Jump faster! The first is right behind you" """)
            print()
            player_instance.life -= 15
            print(f"Heath: {player_instance.life} /100 ")
            print()
            if player_instance.life <= 0:
              death_instance.trap_pitfall_death()
            trap_instance.pitfall_fell = 1

#first time at pitfall trap
  #2 options here Jump accross or down
  if trap_instance.pitfall_trap == True:
    while True:
      choice = str(input("""What do you do?
      Option 1: Run and jump
      Option 2: Jump Down The 10 Feet Hole
      """))
      #Run and jump 3 chances, 2 of them hurt player
      if choice.lower() in("1, Run and Jump, Jump"):
        results = random.choices(
            ["Jumped", "Barely", "Fell"],
            weights = [50, 30, 20]) [0]
        if results == "Jumped":
          print()
          print("""Narrator: "You ran and jumped accross safely making it over" """)
          print()
          trap_instance.pitfall_trap = False
          break
        if results == "Barely":
          print()
          print("""Narrator: "You ran and jumped accross, but your jump was a little short. You slammed your
          stomach into the ledge. Then you pulled yourself up while trying to ignore the pain. You took 3 damage" """)
          print()
          player_instance.life -= 3
          print(f"Heath: {player_instance.life} /100")
          print()
          trap_instance.pitfall_trap = False
          if player_instance.life <= 0:
            death_instance.trap_pitfall_death()
          break
        if results == "Fell":
          print()
          print("""Narrator: "You ran and jumped but you missed and hit your head on the wall, and fell. Taking 15 damage.
          You then used the ladder on the wall to climb up" """)
          print()
          player_instance.life -= 15
          print(f"Heath: {player_instance.life} /100 ")
          print()
          trap_instance.pitfall_trap = False
          if player_instance.life <= 0:
            death_instance.trap_pitfall_death()
          break
      #Jumps down taking reduced damage (NOTE: Best path to take the least amount of damage)
      if choice.lower() in ("2, Jump Down the 10 Feet Hole, Jump Down, Down"):
        print()
        print("""Narrator: "You try to carefully jump down to the bottom of the pit; your legs got hurt a bit from the fall. Taking 3 damage.
        Then you climbed up the ladder to the other side" """)
        print()
        player_instance.life -= 3
        print(f"Heath: {player_instance.life} /100")
        trap_instance.pitfall_trap = False
        if player_instance.life <= 0:
          death_instance.trap_pitfall_death()
        break

#Red tile trap
  #2 Options
    #Grab The Key - player lives
    #Step on the red tile - player dies
def red_tile_trap():
  while True:
    choice = str(input("""What do you do?
    Option 1: Grab The Key
    Option 2: Step On The Red Tile
    """))
    if choice.lower() in("1, Grab The Key, Key"):
      print()
      print("""Narrator: "You walked up to the key ignoring the red tile, as you should. Then you picked up the key.'Rumble'
      Ummm... What was that 'dadadaraaammmaa' ... Wait... RUN RUN NOW! You turn around to run. But you look back one last time to
      see what the Narrator/Me is afraid of. Then you see huge pilars of flames pouring out of the ceiling, around the pedestal and blah blah blah
      STOP LOOKING AND RUN already!" """)
      print()
      break
    if choice.lower() in("2, Step On The Red Tile, Red Tile, Step"):
      print()
      print("""Narrator: 'Sigh' "The ceiling opened above you and a boulder fell on you and roled into the pit" """)
      print()
      death_instance.trap_the_boulder_death()

#Flying Monster Function Section
#1 of 7
#Snuggle Mr. Snuggles
  #Victory? Ending
  #Where the player chose to snuggle his/her way to freedom
    #If you have above 60 life you live
    #But Narrator Dies
def snuggle():
  print()
  print("""Narrator: "You decided to snuggle Mr. Snuggles, walk up slowly and say Snuggle Party!" """)
  print()
  print(f"""{name}: "...snuggle party" """)
  print()
  print("""Narrator: "You gotta say it louder, but not too loud otherwise he'll attack you" """)
  print()
  print(f"""{name}: "Snuggle Party!" """)
  print()
  print("""Narrator: "Mr. Snuggles perked up, looking exicted? It's hard to tell with no face. But he's flying at you with his arms wide open. He sweeps down grabs you,
  lifts you up in the air like a baby and then snuggles you" """)
  #Runs 6 Snuggles -60 damage to player
  for i in range(1,7):
    print()
    print("""Narrator: "Mr.Snuggles snuggles you dealing 10 damage" """)
    print()
    player_instance.life -= 10
    print(f"Health: {player_instance.life} /100")
    print()
    if player_instance.life <=0:
      print()
      print("YOU'VE BEEN SNUGGLED TO DEATH")
      print()
      print(f"""Narrator: "Wow... umm... at least it looked like {name} enjoyed snuggling? Well at least at first..." """)
      print()
      print(f"""Evil Person: "HOW DARE {name} SNUGGLE MY MR. SNUGGLES!" EW! {name} guts are all over him, I'm going to have to give him a bath now. This is going to be
      painful he hates baths..." """)
      exit()
  print()
  print(f"""Narrator: "Hey {name} wake up now's your chance to escape. Mr. Snuggles snuggled himself to sleep. Hurry before he wakes up"  """)
  print()
  print("""Evil Person: "NOOOOOOOOOO HOW DID YOU WIN! MR. SNUGGLES WAKE UP!" """)
  print()
  print("""Narrator: "Mr. Snuggles is waking up hurry!" """)
  print()
  print("""Narrator: "You made it to the door you slam it open and close it right away. You look around to find that you are in... another starting room... with 5 doors this time" """)
  print()
  print("""Evil Person: "HAHAHAHA, the only escape is death" """)
  print()
  print(f"""{name}: "That's not fair, let me out of here already!" """)
  print()
  print("""Narrator: "Don't worry I'll come get you, stay put" """)
  print()
  print("""Evil Person: "Oh no you don't" """)
  print()
  print(f"""{name}: "What, he's coming to me?" """)
  for i in range (1,11):
    print()
    print("...")
    print()
  print("""Narrator: "Oh finally I made it, come on grab my hand" """)
  print()
  print("You notice that the Narrator is very bloody and is missing his right arm, you don't know how he's still standing")
  print()
  print("""Narrator: "Hurry, I trapped Evil Person, but he'll be here soon" """)
  print()
  while True:
    choice = str(input("""Option 1: Grab Hand """))
    if choice.lower() in("1, Grab Hand, Grab"):
      print("""Narrator: "You grabbed my hand, and then I teleported us away, we are free now" """)
      print()
      print(f"""{name}: "Are you okay?" """)
      print()
      print("""Narrator: "No... I'm going to die soon, but at least I'll die free, doing one good deed before I go" """)
      print()
      print(f"""{name}: "Thanks for everything Narrator" """)
      print()
      print("The Narrator collapses, before he hits the ground you catch him and lay him on his back.")
      print()
      print("""Narrator: "They're beautiful..." """)
      print()
      print("You look up, and see a sea of stars that go as far as the eye can see")
      print()
      print("You hear him take his last breath, you looked down and see he is slowly turning into a blue, sparkly powder that is being carried away into the wind")
      print()
      print("Victory?")
      exit()
      break
#Flying Monster Function Section
#2 of 7
#Victory By Running (LOW ODDS)
  #Victory
  #Extremely rare ending very hard to get
    #You get it by running away from suggles very low odds of success but you get many chances
      # 5% chance to make it (NOTE: Used to be 1% but that took way too long to get it for testing purposes)
  #But both the player and Narrator survives
  #There are only two endings that are Victory
def Victory_run():
  print()
  print("""Narrator: "You ran for the door, Mr. Snuggles saw you, and flew you at you with crazy speed. You are just about to reach the door and...
  You made it! You slammed the door shut, and Mr. Snuggles slammed into the door. You can hear him clawwing at the door trying to break it open. You
  look around frantically trying to figure out where to go. But all you see is another starting room... with 5 doors to choose from this time" """)
  print()
  print("""Evil Person: "HAHAHAHAHAHA, you will never leave alive!" """)
  print()
  print("""Narrator: "Hold on I'm almost.... " """)
  print()
  print("'boom' the ceiling above broke and you see a person fall from the ceiling missing his right arm")
  print()
  print("""Narrator: "Hurry grab my hand Evil Person is going to be here soon" """)
  while True:
    choice = str(input("""Option 1: Grab Hand """))
    if choice.lower() in("1, Grab Hand, Grab"):
      print("""Narrator: "You grabbed my hand, and then" 'BOOM' """)
      print()
      print("You looked where the noise came from, there you see a winged creature flying down from the hole that Narrator made")
      print()
      print("""Narrator: "and then we teleport away" """)
      print()
      print("""Evil Person: "NOOOOOOO!" """)
      print()
      print("""Narrator: "We're... (heavy breathing), we're safe now" """)
      print()
      print(f"""{name}: "Are you okay?" """)
      print()
      print("""Narrator: "Yeah, (heavy breathing) teleporting that far away takes a toll on my body" """)
      print()
      print(f"""{name}: "But you're missing an arm, and it's bleeding out" """)
      print()
      print("He looks at his right shoulder and waves his left hand over it and he closed up the wound")
      print()
      print("""Narrator: "I should be fine now, now lets get something to eat. I haven't eaten anything for a few decades, and you look starving" """)
      print()
      print(f"""{name}: "Wait, what about Evil Person will he find us?" """)
      print()
      print("""Narrator: "Eventually he will, and he definitely will if we don't leave soon he could track my trail I left my teleport. but don't worry
      when he comes we'll be ready to fight together" """)
      print()
      print(f"{name} and Narrator picked a random direction and started walking. Walking under a sea of stars that go as far as the eye can see")
      print()
      print("Victory")
      exit()
      break

#Fight Flying Monster Function
#3 of 7
#Plot Armor: 1st Death
  #Player died once but it's not the end
  #The player get's PLOT ARMOR
  #Giving the player extra life and extra damage
def plot_armor():
  if player_instance.life <= 0:
    print()
    print("""Narrator: "You died..." """)
    print()
    print("""Evil Person: "HAHAHAHA, I knew you were weak, but how dare you harm Mr. Snuggles!" """)
    print()
    print("""Narrator: "I won't let it end this way" """)
    print()
    print(f"""Evil Person: "What? There's nothing you can do {name} is dead" """)
    print()
    print("""A holy light beamed down on top of you bringing you back to life and healing all of you injuries""")
    print()
    print(f"""Narrator: "{name} wakes up feeling stronger, and better than ever" """)
    print()
    print(f"""{name}: "What? How am I still alive?" """)
    print()
    print("""Narrator: "Plot Armor" """)
    print()
    print(f"""{name}: "Plot Armor?" """)
    print()
    print("""Narrator: "Plot Armor" """)
    print()
    print("""Evil Person: "You, you can't do that, that's against the rules!" """)
    print()
    print(f"""Narrator: "Well I just did, soooo I obviously can. {name}, now's your chance your life is at 333, and you should be
    able to do five times the amount of damage now. But the triple damage won't last long, so hurry up and kill Mr. Snuggles" """)
    print()
    print("""Evil Person: "HOW DARE YOU THREATEN MR. SNUGGLES, I WILL TEAR YOU LIMB FROM LIMB! YOU BETTER RUN!" """)
    print()
    print(f"""Narrator: "{name}, I gotta go, he's coming for me, you must fight, fight till your last breath. I'll try to
    help you when I can" """)
    print()
    player_instance.revive = True


#Fight Flying Monster Function
#4 of 7
#Running
  #Running function with random chance to escape
  #Leads to victory ending, but very low odds to get, and it punishes the player harshly for trying
def Snuggles_run():
  results = random.choices(
      ["Run", "Failed", "Close"],
      [5, 60, 35])[0]
  if results == "Run":
    player_instance.victory_run = True
    #Escaped and won
    Victory_run()
  if results == "Failed":
    print()
    print(f"""Narrator: "You tried running to the door but Mr. Snuggles flew up to you easily. Grabbed you with his claws piercing
    into you and threw you away from the door. Dealing 15 damage" """)
    print()
    damage = 15
    if player_instance.revive == True: #Damage goes to 2nd life if died once
      player_instance.revive_life -= damage
      if player_instance.revive_life <= 0: #If died two times
        return death_instance.plot_armor_death_from_Snuggles()
        exit()
    if player_instance.revive == False: #Damage goes to 1st life
      player_instance.life -= damage
      plot_armor() #Function: If died once do this function
    if player_instance.revive == False:
        print(f"Heath: {player_instance.life} /100")
    if player_instance.revive == True:
      print(f"Heath: {player_instance.revive_life} /333")
    print()
  if results == "Close":
    print()
    print("""Narrator: "You tried running to the door and you almost made it, but Mr. Snuggles grabbed you with his claws piercing
    into you and threw you away from the door. Dealing 15 damage" """)
    print()
    damage = 15
    if player_instance.revive == True: #Damage goes to 2nd life if died once
      player_instance.revive_life -= damage
      if player_instance.revive_life <= 0: #If died two times
        return death_instance.plot_armor_death_from_Snuggles()
        exit()
    if player_instance.revive == False: #Damage goes to 1st life
      player_instance.life -= damage
      plot_armor() #Function: If died once do this function
    if player_instance.revive == False:
        print(f"Heath: {player_instance.life} /100")
    if player_instance.revive == True:
      print(f"Heath: {player_instance.revive_life} /333")
    print()
  Snuggles_instance.attack_turns = 0

#Fight Flying Monster Function
#5 of 7
#LATER UPDATE: MAKE DIFFERENT DODGE CHANCES FOR WHEN HES FLYING AND ON THE GROUND
  #ALSO MAKE DIFFERENT ATTACK DAMAGES FOR WHEN HES IN THE AIR OR GROUND
#Dodge Section
  #Has 3 random chances
    #Dodge - take no damage increase attack_turns to two
    #Partial Dodge - take partial damage and increase attack_turns to one
    #Failed - take damage
def dodge_Snuggles():
  result = random.choices(
      ["Dodge", "Partial Dodge", "Failed"],
      weights = [20, 40, 40])[0]
  if result == "Dodge":
    print()
    print("Narrator: You dodged and Mr. Snuggles went flying past you!")
    #two turn before he can attack you back
    Snuggles_instance.attack_turns = 3
  if result == "Partial Dodge":
    damage = Snuggles_instance.damage() /2

    #Damage goes to 2nd life if died once
    if player_instance.revive == True:
      player_instance.revive_life -= damage
      print()
      print(f"Narrator: You dodged, but Mr. Snuggles grazed you with his claws dealing {damage} damage!")
      print()
      print(f"Heath: {player_instance.revive_life} /333")
      print()
      #If died two times
      if player_instance.revive_life <= 0:
        #Plays actual death
        return death_instance.plot_armor_death_from_Snuggles()
        exit()

    #Damage goes to 1st life
    if player_instance.revive == False:
      player_instance.life -= damage
      print()
      print(f"Narrator: You dodged, but Mr. Snuggles grazed you with his claws dealing {damage} damage!")
      print()
      print(f"Heath: {player_instance.life} /100")
      print()
      #Function: If died once do this function
      plot_armor()
    print()
    #One turns before he can attack you back
    Snuggles_instance.attack_turns = 2
  if result == "Failed":
    damage = Snuggles_instance.damage()
    #Damage goes to 2nd life if died once
    if player_instance.revive == True:
      player_instance.revive_life -= damage
      #If died two times
      if player_instance.revive_life <= 0:
        #Plays actual death
        return death_instance.plot_armor_death_from_Snuggles()
        exit()
    #Damage goes to 1st life
    if player_instance.revive == False:
      player_instance.life -= damage
      print(f"Narrator: You fell trying to dodge and Mr. Snuggles clawed you dealing {damage} damage!")
      print()
      print(f"Heath: {player_instance.life} /100")
      print()
      #Function: If died once do this function
      plot_armor()
    print()

#Fight Flying Monster Function
#6 of 7
#Bone Sword section
  #Fight Snuggles with a sword
    #3 options
      #Attack with the sword - plays attack function
      #Dodge - plays dodge function
      #Run for the door - plays run function
def fight_Snuggles_sword():
  #if Snuggle is alive
  if Snuggles_instance.life > 0:
    print()
    print("""Narrator: "Quick Tip, after a successful dodge Mr. Snuggles can't attack you for 2 turns. You got this!" """)
    print()
    while True:
      choice = str(input("""What do you do?
      Option 1: Attack With Bone Sword
      Option 2: Dodge
      Option 3: Run For The Door
      """))
      #Attack
        #if player types in any of these do this:
      if choice.lower() in("1", "Attack With Bone Sword", "Bone Sword", "Attack", "Sword"):
        #If player died once
        if player_instance.revive == False:
          attack_sword()
          Snuggles_instance.life -= weapons_instance.damage
          print()
          if weapons_instance.damage > 0:
            print()
            print(f"Mr. Snuggles Heath: {Snuggles_instance.life}/666")
          print()
        #if player didn't die yet
        if player_instance.revive == True:
          attack_sword()
          Snuggles_instance.life -= weapons_instance.damage
          if weapons_instance.damage > 0:
            print()
            print(f"Mr. Snuggles Heath: {Snuggles_instance.life}/666")
          print()
          #If Mr. Snuggles has zero life(dead) do this:
        if Snuggles_instance.life <= 0:
          victory_deaths_snuggles_evilperson()
          break
          #If Mr. Snuggles has zero or less than zero turns left it can attack again
        if Snuggles_instance.attack_turns == 0:
            damage = Snuggles_instance.damage()
            print()
            print(f"""Narrator: "Mr. Snuggles attacked back and did {damage} damage" """)
            print()
            #Damage goes to 2nd life if died once
            if player_instance.revive == True:
              player_instance.revive_life -= damage
              print()
              print(f"Heath: {player_instance.revive_life} /333")
              #If died two times
              if player_instance.revive_life <= 0:
                #Plays death
                return death_instance.plot_armor_death_from_Snuggles()
                exit()
            #Damage goes to 1st life
            if player_instance.revive == False:
              player_instance.life -= damage
              print()
              print(f"Heath: {player_instance.life} /100")
              #Function: If died once do this function
              plot_armor()
            print()
        #If Mr. Snuggles has more than zero turns left it can't attack
        if Snuggles_instance.attack_turns >= 1:
          Snuggles_instance.attack_turns -= 1
          print(f"""Narrator: "Mr. Snuggles is dizzy from the attack, {Snuggles_instance.attack_turns} turn left""")
          print()
      if choice.lower() in ("2", "Dodge"):
        dodge_Snuggles()
        print()
        #>=1 That way when 0 turns are left it will attack
        if Snuggles_instance.attack_turns >= 1:
          Snuggles_instance.attack_turns -= 1
          print(f"""Narrator: "Mr. Snuggles is dizzy from the attack, {Snuggles_instance.attack_turns} turn left""")
          print()
      if choice.lower() in ("3", "Run For The Door","Run", "Door"):
        Snuggles_run()

#Fight Flying Monster Function
#7 of 7
#Bone Whip section
  #Fight Snuggles with a whip
    #3 options
      #Attack with the sword - plays attack function
      #Dodge - plays dodge function
      #Run for the door - plays run function
def fight_Snuggles_whip():
  #if Snuggle is alive
  if Snuggles_instance.life > 0:
    print()
    print("""Narrator: "Quick Tip, after a successful dodge Mr. Snuggles can't attack you for 2 turns. You got this!" """)
    print()
    while True:
      choice = str(input("""What do you do?
      Option 1: Attack With Bone Whip
      Option 2: Dodge
      Option 3: Run For The Door
      """))
      #Attack
      if choice.lower() in("1", "Attack With Bone Whip", "Bone Whip", "Attack", "Whip"): #if player types in any of these do this:
        #if died once
        if player_instance.revive == False:
          attack_bone_whip()
          Snuggles_instance.life -= weapons_instance.damage
          print()
          if weapons_instance.damage > 0:
            print()
            print(f"Mr. Snuggles Heath: {Snuggles_instance.life}/666")
          print()
        #if didn't die yet
        if player_instance.revive == True:
          attack_bone_whip()
          Snuggles_instance.life -= weapons_instance.damage
          if weapons_instance.damage > 0:
            print()
            print(f"Mr. Snuggles Heath: {Snuggles_instance.life}/666")
          print()
        #If Mr. Snuggles has zero life(dead) do this:
        if Snuggles_instance.life <= 0:
          victory_deaths_snuggles_evilperson()
          break
        #If Mr. Snuggles has zero or less than zero turns left it can attack again
        if Snuggles_instance.attack_turns == 0:
            damage = Snuggles_instance.damage()
            print()
            print(f"""Narrator: "Mr. Snuggles attacked back and did {damage} damage" """)
            print()
            #Damage goes to 2nd life if died once
            if player_instance.revive == True:
              player_instance.revive_life -= damage
              print()
              print(f"Heath: {player_instance.revive_life} /333")
              #If died two times
              if player_instance.revive_life <= 0:
                #plays death
                return death_instance.plot_armor_death_from_Snuggles()
                exit()
            #Damage goes to 1st life
            if player_instance.revive == False:
              player_instance.life -= damage
              print()
              print(f"Heath: {player_instance.life} /100")
              #Function: If died once do this function
              plot_armor()
            print()
        #If Mr. Snuggles has more than zero turns left it can't attack
        if Snuggles_instance.attack_turns >= 1:
          Snuggles_instance.attack_turns -= 1
          print(f"""Narrator: "Mr. Snuggles is dizzy from the attack, {Snuggles_instance.attack_turns} turn left""")
          print()
      if choice.lower() in ("2", "Dodge"):
        dodge_Snuggles()
        print()
        #>=1 That way when 0 turns are left it will attack
        if Snuggles_instance.attack_turns >= 1:
          Snuggles_instance.attack_turns -= 1
          print(f"""Narrator: "Mr. Snuggles is dizzy from the attack, {Snuggles_instance.attack_turns} turn left""")
          print()
      if choice.lower() in ("3", "Run For The Door","Run", "Door"):
        Snuggles_run()

#Killed Snuggles
  #Victory
  #The second Victory spot, it is a good ending
  #
def victory_deaths_snuggles_evilperson():
  print()
  print("""You blinked and then you see a person with black wings kneeling down and holding Mr. Snuggles body""")
  print()
  print(f"""Evil Person: "You killed him, you killed Mr. Snuggles, {name} killed him... you will never escape alive" """)
  print()
  print("""He lunges at you but he's to fast for you to react, he stops an inch away from your head. You notice another person who's missing his right arm
  holding Evil Person's arm back.""")
  print()
  print("""Narrator: "I won't let you kill anymore people" """)
  print()
  print("""Evil Person: 'Rrraaagh' "I'LL KILL YOU ALL" """)
  print()
  if player_instance.has_sword:
    print("Evil Person pulls out a bone whip and attacks Narrator with it")
    print(f"""Narrator: "Hurry {name} we must work together if we are going to beat him." """)
    print()
    print("A holy light beamed down on top of you healing all of you injuries and giving you a speed boost")
    print()
    print("""Narrator: "With the speed boost you should be able to see hit him back" """)
    print()
    print("""Evil Person: "HAHAHAHA even with your stupid boosting powers I will still crush both of you by myself" """)
  if player_instance.has_whip:
      print("Evil Person pulls out a bone sword and attacks Narrator with it")
      print()
      print(f"""Narrator: "Hurry {name} we must work together if we are going to beat him." """)
      print()
      print("A holy light beamed down on top of you healing all of you injuries and giving you a speed boost")
      print()
      print("""Narrator: "With the speed boost you should be able to see hit him back" """)
      print()
      print("""Evil Person: "HAHAHAHA even with your stupid boosting powers I will still crush both of you by myself" """)
  print()
  print(f"""{name} and Narrator takes on a flurry of attacks from Evil Person, but they are quick. They are able to dodge and deflect many blows.
  The blow Evil Person manages to land on the duo are only glancing blows. The battle lasts for what seems like hours; all it takes it someone to
  make one small mistake, one blow, to end the fight. The fighters are exhausted {name} looks ready to pass out. Minutes pass, the battle still rages
  on with no clear victory in sight... Oh wait, it looks like {name} is starting to get sloppy, Evil Person catches on and sends an attack at {name}.
  Narrator Seizes the opportunity and moves and parries the blow. Evil Person is thrown off, You and Narrator take that chance and stike him. Leaving
  huge gapping holes in his chest.""")
  print()
  print("""Narrator: "(panting) That was very close, I thought you were going to die for a second there." """)
  print()
  print(f"""Evil Person: "(Spitting out blood as he talks) How? How did you beat me and Mr. Snuggles? {name} you deserve to die for killing him.
  (barfs out blood) But I guess I get to see Mr. Snuggles again real soon. Oh wait are we both going to Hell. Do animals go to Hell for eating people?
  I guess I'll find out soon." """)
  print()
  print("Evil Person collaspes to the ground the duo are victorious now they can escape together")
  print()
  print(f"""Narrator: "Come {name} take my hand let's get out of here" """)
  print()
  while True:
    choice = str(input("""Option 1: Grab Hand """))
    if choice.lower() in("1, Grab Hand, Grab"):
      print("""Narrator: "You grabbed my hand, and then I teleported us away, we are free now" """)
      print()
      print("You both look around and see that night has fallen, and above you lies a sea of stars")
      print()
      print(f"""{name}: "What do we do now?" """)
      print()
      print("""Narrator: "Lets just enjoy the view for a little bit and figure that bit out later." """ )
      print()
      for i in range(1-6):
        print()
      print(f"""Congrats {name}!!!
      You beat the game and both you and Narrator survived, also Narrator is dead.
      This is the best ending.

      End Credits:
        Bulit by Adam Larson
        ChatGPT helped me with some grammar, some debugs, and helped teach me about classes and for loops
          NOTE: I didn't copy and paste any code, other than fixing some challenging bugs!
                But I did take inspiration from some dialogue suggestions and added bits and pieces in there in a few spots
                For Example it helped me pick out Mr. Snuggles Name and helped me describe some of his features.

      There are 10 endings including this ending, death endings also count
      4 endings are rare
            1 Victory?
            3 Deaths
      Can you find them all? """)
      print()
      break
  while True:
    choice = str(input("""Do you want a hint?
    Option 1: Yes
    Option 2: Nah I'll find them"""))
    if choice.lower() in("1, Yes, yep, please help"):
      print()
      print("""Hint:
      Victory?: RUN
          Difficulty: Rare only a 5% chance to get it but it's rare because you can try it over and over again
      Death 1: Arrows are pointy
          Difficulty: Kinda Hard
      Death 2: Eww it's sticky
          Difficulty: Impossible unless you have very bad luck or should I saw good luck?
      Death 3: Fall
          Difficulty: Very Rare only a 0.8 percent to get it
      """)
      break
    if choice.lower() in("2, Nah I'll find them, Nah I'd win, No, Nope, Notta"):
      print()
      print("""Good Luck Adventures!!
      But just to warn you some of them have a very very very low chance to get I added them in there as a lottery thing (well an unlucky loterry MUHAHAHAHAHA)
      So anyways, what I'm saying is don't stress out about getting all the endings, there's no achievements just play to have fun that's what games are for
      ...not to spiral into an existential crisis because you missed a dialogue option   (just read my very sloppy code if you want all the dialogue)""")
  exit()




#For testing attack chances
# for i in range (1,10):
#   attack_sword()

# for i in range (1,10):
#   attack_bone_whip()




#Function for the Start Room
  # 4 Options
    #Green Door - Enters green room
    #Yellow Door - Enters Yellow Room if you have yello key
    #Red Door - Enters Red Room if you have red key
    #Do nothing - you do nothing
def start():
  #First time in starting room
  if rooms_instance.start_room == False:
    print()
    while True:
      choice = str(input("""
      Option 1: Open Green Door
      Option 2: Open Yellow Door
      Option 3: Open Red Door
      Option 4: Do Nothing
      """))
      if choice.lower() in("open green door", "1", "green"):
        print()
        print("You opened the green door")
        return green()
      if choice.lower() in("open yellow door", "2", "yellow"):
          if player_instance.try_yellow_locked_door == True and player_instance.try_red_locked_door == True:
            print()
            print("""Narrator: "The yellow door is locked. You notice a key hole. """)
            print()
            print("""Evil Person: "HAHAHAHA YOU WILL NEVER ESCAPE ALIVE!!!" """)
            print()
            print(f"""Narrator: "Hey {name}, is playing it smart, trying everything out. (Whispers to you) Hey, you are just
            trying the door, right? You did see that the door said locked on it, right? I hope you aren't dumb.""")
            print()
            print(f"""{name}: "Why didn't you tell me that in the first place!" """)
            print()
            print("""Narrator: "SORRRRRYYYY, for assuming that you could read basic Keztral!" """)
            print()
            print(f"""{name}: "Keztral?" """)
            print()
            print("""Narrator: "Oh you never heard of it... now I feel like a jerk? Basically, it's [ERORR: INFORMATION REDACTED],
            then it's [ERORR: INFORMATION REDACTED]. Do you get it now? """)
            print()
            print(f"""{name}: ??? """)
            print()
            print(f"""{name}: "Just read everything out to me from now on" """)
            print()
            print("""Narrator: "Fine, the red door also says locked on it" """)
            print()
            print(f"""Evil Person: "HAHAHA, {name} doesn't even know how to read!" """)
            player_instance.try_yellow_locked_door = False
          #If player has gone to red or yellow door before print this:
          else:
            print("Narrator: The yellow door is still locked...")

      if choice.lower() in("open red door", "3", "red"):
          if player_instance.try_yellow_locked_door == True and player_instance.try_red_locked_door == True:
            print()
            print("""Narrator: "The red door is locked. You notice a key hole. """)
            print()
            print("""Evil Person: "HAHAHAHA YOU WILL NEVER ESCAPE ALIVE!!!" """)
            print()
            print(f"""Narrator: "Hey {name}, is trying his best. (Whispers to you) Hey, you are just
            just trying the door right? You did see that the door said locked on it, right?""")
            print()
            print(f"""{name}: "Why didn't you tell me that in the first place!" """)
            print()
            print("""Narrator: "SORRRRRYYYY, for assuming that you could read basic Keztral!" """)
            print()
            print(f"""{name}: "Keztral?" """)
            print()
            print("""Narrator: "Oh you never heard of it... now I feel like a jerk? Basically, it's [ERORR: INFORMATION REDACTED],
            then it's [ERORR: INFORMATION REDACTED]. Do you get it now? """)
            print()
            print(f"""{name}: ??? """)
            print()
            print(f"""{name}: "Just read everything out to me from now on" """)
            print()
            print("""Narrator: "Fine, the yellow door also says locked on it" """)
            print()
            print(f"""Evil Person: "HAHAHA, {name} doesn't even know how to read!" """)
          #If player has gone to red or yellow door before print this:
          else:
            print("Narrator: The red door is still locked...")

  #If you have gone to the start room after you completed green room
  if rooms_instance.start_room == True:
    print("Narrator: You are now in the starting room again")
    while True:
      choice = str(input("""What do you do?
      Option 1: Open Green Door
      Option 2: Open Yellow Door
      Option 3: Open Red Door
      """))
      if choice.lower() in ("1, Open Green Door, Green"):
        return green()
      if choice.lower() in ("2, Open Yellow Door, Yellow"):
        if rooms_instance.left_yellow_room == True:
          print()
          print("""Narrator: "The room is still on fire I wouldn't go in there again" """)
          print()
          continue
        if player_instance.has_yellow_key == True and rooms_instance.yellow_room == False:
          print()
          print(""" Narrator: "You walk up to the yellow door and pull out your yellow key.
          You stick it in and 'click' the door slams down to the ground. You head inside." """)
          return yellow()
        else:
          print("""Narrator: "The yellow door is still locked..." """)
      if choice.lower() in ("3, Open Red Door, Red"):
        if player_instance.has_red_key == True:
          print()
          print(""" Narrator: "You walk up to the red door and pull out your red key.
          You stick it in and 'click' the door slams down to the ground. You head inside." """)
          print()
          return red()
        else:
          print("Narrator: The red door is still locked...")


#Green Room
  #Function: Slime Monster, attacking with sword and whip
def green():
  #If you entered the green roomfor the first time
  if rooms_instance.green_room == False:
    print()
    print("""Narrator: "As you enter the green room the door slams shut behind you,
    and you hear a click behind you. That probably means the door has been locked. In
    front of you, you see three pedestals with a object on each pedestal. The left one has
    a bone sword, the middle, a bone whip, and the the right one has a Rubber Duck on it. Which
    item will you choose."

    Evil Person: "Oh boy, this is gonna be good, please try to last longer than the last person." """)

    print()
    print(
    name+""": Last person!?

    Narrator: ...
      """)

#Choose your weapon
    while True:
      choice = str(input("""
      Option 1: Left Pedestal, Bone Sword
      Option 2: Middle Pedestal, Bone Whip
      Option 3: Right Pedestal, Rubber Duck
      Option 4: Try The Door
      """))

      if choice.lower() in("1, Left Pedestal, Left, Bone Sword, Sword"):
        return green_chose_bone_sword()
      if choice.lower() in("2, Middle Pedestal, Middle, Bone Whip"):
        return green_chose_bone_whip()
      if choice.lower() in("3, Right Pedestal, Rubber Duck, Duck, Right"):
        print("""Narrator: "You walked up to the Right Pedestal and grabbed the Rubber Duck off of it.
        All of a sudden the pedestals dropped into the ground into an endless void. You tried
        looking into the hole that the Right Pedestal fell in, but a tile that looks like the
        ground magically apeared covering the hole. You looked at the other spots where the
        pedestals were at and now you can't even tell where they fell from. While you were
        distracted from the falling pedestals, you completely tuned out the sound of a squishing,
        splatting, sound behind you... It is creeping closer, and CLOSER... ITS ABOUT TO ATTACK!!!
        """)
        while True:
          if player_instance.life > 0:
            damage = slime_instance.damage()
            player_instance.life -= damage
            print(f"""Narrator:"The Slime attacked and did {damage} damage" """)
            print(f"Heath: {player_instance.life} /100")
          if player_instance.life <= 0:
            print(f"YOU HAVE DIED!")
            print()
            print(f"""Narrator: "{name}, why on Earth did you choose the Rubber Duck! You can't fight back!""")
            print()
            print(f"""Evil Person: "HAHAHAHA! I knew you would die with your stupid name. {name}, that's
            almost slightly better than Narrator HAHAHAHA!""")
            print(f"\n {name} is dead")
            break
        exit()
        break
      if choice.lower() in("4, Try The Door, door"):
        if rooms_instance.yellow_door_locked == 0:
          print()
          print("""Narrator: "The door is locked..." """)
          print()
          rooms_instance.yellow_door_locked = 1
          continue
        if rooms_instance.yellow_door_locked == 1:
          print()
          print("""Narrator: "The door is still locked..."
          (Whispers): "You imbecile" """)
          print()
          rooms_instance.yellow_door_locked = 2
          continue
        if rooms_instance.yellow_door_locked == 2:
          print()
          print(""" Narrator: ... """)
          print()
          print(""" Evil Person: "HAHAHAHA, look """ + name + """ is trying to run away! HAHAHAHA!""")
          print()
          print(""" Narrator: ... """)
          continue
          #MAYBE LATER ADD IT UP TO 5 AND HAVE THE NARRATOR KILL YOU TO GET A NEW PERSON
  #If you already visted the green room
  if rooms_instance.green_room == True:
    print("""Narrator: You look around again and there's nothing here. Then you go back to the
    starting room.""")
    return start()

#If player chooses the bone_sword play this
def green_chose_bone_sword():
  print("""Narrator: "You walked up to the Left Pedestal and grabbed the Bone Sword off of it.
          All of a sudden the pedestals dropped into the ground into an endless void. You tried
          looking into the hole that the Left Pedestal fell in, but a tile that looks like the
          ground magically apeared covering the hole. You looked at the other spots where the
          pedestals were at and now you can't even tell where they fell from. While you were
          distracted from the falling pedestals, you completely tuned out the sound of a squishing,
          splatting, sound behind you... It is creeping closer, and closer... ITS ABOUT TO ATTACK!!!
          """)
#Calls function to fight slime with bone sword
  fight_slime_sword()
  player_instance.has_sword = True
  player_instance.has_yellow_key = True

  while True:
    choice = str(input("""What do you do?
    Option 1: Leave room
    Option 2: Look around
    """))
    if choice.lower() in("1", "Leave Room", "Leave"):
      print()
      print("Narrator: You decided to leave.")
      print()
      rooms_instance.start_room = True
      rooms_instance.green_room = True
      return start()
    if choice.lower() in ("2", "Look Around", "Look"):
      print("""Narrator: You looked around and found nothing. Do you really have that little faith
      in me? I would have told you eariler if there was other stuff in there? """)
      print()


#If player chooses bone_whip play this
def green_chose_bone_whip():
  print("""Narrator: "You walked up to the Middle Pedestal and grabbed the Bone Whip off of it.
          All of a sudden the pedestals dropped into the ground into an endless void. You tried
          looking into the hole that the Middle Pedestal fell in, but a tile that looks like the
          ground magically apeared covering the hole. You looked at the other spots where the
          pedestals were at and now you can't even tell where they fell from. While you were
          distracted from the falling pedestals, you completely tuned out the sound of a squishing,
          splatting, sound behind you... It is creeping closer, and CLOSER... ITS ABOUT TO ATTACK!!!
          """)
  #Calls function to fight slime with bone whip
  fight_slime_monster_bone_whip()
  player_instance.has_whip = True
  player_instance.has_yellow_key = True

  while True:
    choice = str(input("""What do you do?
    Option 1: Leave room
    Option 2: Look around
    """))
    if choice.lower() in("1", "Leave Room", "Leave"):
      print()
      print("Narrator: You decided to leave.")
      print()
      rooms_instance.start_room = True
      rooms_instance.green_room = True
      return start()
    if choice.lower() in ("2", "Look Around", "Look"):
        print("""Narrator: You looked around and found nothing. Do you really have that little faith
      in me? I would have told you eariler if there was other stuff in there? """)
        print()

#Yellow Room
  #Functions: Traps
def yellow():
  print()
  print("""Narrator: "You have now entered the yellow room... and you see an arrow trap shooting already shooting,
  a pitfall trap that isn't covered at all  with a ladder to get out, a sign at the way end of the hall that says 'DO NOT STEP ON RED TILE',
  and at the way end you see a red key in a pedestal" """)
  print()
  print("""Evil Person: "WAIT WHAT! How did I forget to cover up every single trap? Where did that sign even come from, I didn't
  put that there?" """)
  print()
  print(f"""Narrator: "HAHAHAHA! ...sorry that (ahem), anyways {name} you got this just be careful" """)
  print()
  print("""Evil Person: "Once I find out who did this they'll be thrown in here next, and Narrator if I find out it was you, you can forget about
  ever seeing the light of day again" """)
  print()
  print("""Narrator: ... """)
  print()
  print(f"""Narrator: "{name}, just take it slow alright you can still make it out. The first trap you have to deal with is the arrow trap" """)
  print()
  arrow_trap()
  print("""Narrator: "Alright, next up is the pitfall trap it looks about 10 feet deep, and there is a ladder on the other side of the hole." """)
  print()
  pitfall_trap()
  print()
  print("""Narrator: "Now you can walk right up to the key, just don't step on the red tile" """)
  red_tile_trap()
  if player_instance.death_script == True:
    exit()
  print()
  print("""Narrator: "Hurry quick jump accross the pit again" """)
  pitfall_trap()
  print()
  print("""Narrator: "Now run through the arrow trap" """)
  print()
  arrow_trap()
  print()
  print("""Narrator: "You made it out of the yellow room. You turned back to see that the whole room is on fire now. You can't even step in without getting burned...
  Well now you have the red key one more room to go and you'll be free... (whispers) probably..." """)
  print()
  print("""Evil Person: "I can't believe you made it out alive it's not fair at all. All that work for nothing... I guess you can still die in the next room. Yeah the next
  room, the red room, MUHAHAHAHAHA, you'll never win against my beautiful pet." """)
  player_instance.has_red_key = True
  rooms_instance.left_yellow_room = True
  start()


#Red Room Funtion Boss Fight
  #3 Options
    #Fight - fight Snuggles
    #Snuggle - Special ending if more than 60 life you get Victory?
    #Run - if failed at running go into fight function
def red():
  print()
  print("""Narrator: "You are now inside the red room, you hear a mechanical screeching sound behind you. You turned around and see that the walls are converging, closing
  up the hole that the door left. It slowly slamed shut. it's pitch dark you can't see a thing. slowly you hear a drum banging, 'boom', 'boom' 'boom' on repeat. Then you hear
  violins, piano, trumpets, a whole orchestra is playing now... They all stopped out of no where. You see a light now, multiple lights shinning down in the distance. Then a choir
  in a low whispery voice started singing. As a creature, rose from the ground just out of reach of the lights, as it got higher, the orchestra slowly came back again. The choir
  is singing louder and louder. Now the whole creature is out of the ground. The creature now slowly stepped into the lights, it's a" """)
  print()
  print("""Evil Person: "I got it from here. You see a pitch black humaniod body step into the lights. Where it's face should have been was nothing, no eyes, no mouth, just smooth, empty
  skin. In his chest there's a gaping hole where it's heart should be. His hands has sharp, long back claws, that can easily slice down a heavily armored knight. His scaly skin is
  nearly as strong as a dragon's hide. He walked further into the light, and you see that it has sharp, long black bone wings sticking out of his back. With a long razor sharp tail, that
  looks like a scorpian's tail, it can pierce through almost anything. This terrifyingly beautiful creature's name is... MR. SNUGGLES!. """)
  print()
  print("""Narrator: "...Mr. Snuggles?" """)
  print()
  print("""Evil Person: "Yeeeess, Mr. Snuggles" """)
  print()
  print("""Narrator: "HAHAHAHAHA, why did you name a creature like that Mr. Snuggles, it's ridiculous" """)
  print()
  print("""Evil Person: "HOW DARE YOU I'M GOING TO GRIND YOU TO A PULP, AND USE YOUR BONES AS FERTILIZER!" """)
  print()
  print("""Evil Person: "...But if you must know I named him Mr. Snuggles, because he likes to snuggle with me at night, plus he has a weird habit of snuggling his victims to death" """)
  print()
  print(f"""Narrator: "Okay fine, it's a decent name, at least it's better than Evil Person. Anyways So {name} you have to fight Mr. Snuggles" """)
  print()
  print(f"""{name}: "HOW AM I SUPPOSED TO WIN IF I CAN'T EVEN HURT HIM" """)
  if player_instance.has_sword == True:
    print()
    print("""Evil Person: "Don't worry, did you really think I would make it imposible for you to win? Look at his wings, they look sort of off... like it's missing a few pieces... """)
    print()
    print(f"""{name}: "...Can he not fly or something" """)
    print()
    print("""Evil Person: (sigh) "You look down at your bone sword and reailse that, your sword was from it's wings. So with it you can hurt Mr. Snuggles. BUT YOU BETTER NOT OR I'LL KILL YOU" """)
    print()
  if player_instance.has_whip == True:
    print()
    print("""Evil Person: "Don't worry, did you really think I would make it imposible for you to win? Look at his wings, they look sort of off... like it's missing a few pieces... """)
    print()
    print(f"""{name}: "...Can he not fly or something" """)
    print
    print("""Evil Person: (sigh) "You look down at your bone whip and reailse that, your whip was from it's wings. So with it you can hurt Mr. Snuggles. BUT YOU BETTER NOT OR I'LL KILL YOU" """)
    print()
  print(f"""{name}: "Wait so you are going to kill me if I hurt him, and Mr. Snuggles will snuggle me to death if I don't. How do I get out of this alive?" """)
  print()
  print("""Narrator: "You could try to fight him or if you snuggle him back maybe you can survive the snuggle and make it out the door behind him" """)
  print()
  print(f"""{name}: "There's a door? Is it locked, can't I just try to run past him? He has no eyes, and no ears so I should be able to get past him." """)
  print()
  print("""Narrator: "He's sort of like a bat, he can 'see' his surroundings at all times by sending out his mana. So you could try running to the door, but he's
  pretty fast so I doubt you could make it" """)
  print()
  while True:
    choice = str(input("""What do you do?
    Option 1: Fight Mr. Snuggles
    Option 2: Snuggle Mr. Snuggles
    Option 3: Run For The Door
    """))
    if choice.lower() in("1, Fight Mr. Snuggles, Fight"):
      print()
      print("""Narrator: "You decided to fight Mr. Snuggles, good luck!" """)
      print()
      if player_instance.has_sword == True:
        return fight_Snuggles_sword()
      if player_instance.has_whip == True:
        return fight_Snuggles_whip()

    if choice.lower() in ("2, Snuggle Mr. Snuggles, Snuggle"):
      return snuggle()

    if choice.lower() in ("3, Run For The Door, Run, Door"):
      Snuggles_run()
      if player_instance.victory_run == True:
        exit()
      if player_instance.victory_run == False:
        if player_instance.has_sword == True:
          print("""Narrator: "Now you gotta FIGHT!" """)
          return fight_Snuggles_sword()
        if player_instance.has_whip == True:
          print("FIGHT")
          return fight_Snuggles_whip()



  #***Possible Future Update Make it where you actually fight Evil Person***
  #Note (Control-/) to comment multiple lines
  # print("""Narrator: "Tip: I can attack him when you 'Pin Him Down' but you can only pin him once every two turns
  #                     "Tip 2: Evil Person is too fast to dodge, so I will try to block his attacks but I can die if I take too much damage" """)
  # while True:
  #   choice = str(input("""What do you do?
  # Option 1: Attack
  # Option 2: Narrator Block
  # Option 3: Pin Him Down
  #   """))
  #   if choice.lower() in("1", "Attack"):
  #     pass
  #   if choice.lower() in("2", "Narrator Block", "Block")
  #     pass
  #   if


#Starting Text
name1 =input("""
Evil Person: "hello... Hello... HELLLLLLOOOOoooo!
Oh good you are finally awake. Now try to escape my dungeon. If you
escape you will find riches, fame, and my anger. My death trap is so amazing
it should easily kill someone of your standing. Get up now what do you see."

Narrator: "As you can see you are in a square room with nothing in it except 3 doors.
There is a green door, a yellow door, and a red door. What path will you take?"

Evil Person: "Umm was that you talking just now?... no? Huh I thought I got rid
of that pesty ghost. Oh well I can just send it to the after life after I watch you die.

Narrator: "...Anyways, what is your name?"
""")
print()
print("""
Evil Person: "HAHAHA what a stupid name!"

Narrator: "Shut up already it's better than having your name be "Evil Person"

Evil Person: ...

Narrator: "But he's sort of right you can pick a different name if you want to."
""")
print()
#Sets the variable name
name = input()

#if player choose the same name twi3ce play this
if name1 == name:
  print("""
  Narrator: "Oh okay, you don't want to change. That's okay...
  um... your name is starting to grow on me...
  """)
else:
  print("""
  Narrator: "Yeah that's a way better name good choice."

  Evil Person: "...I actually prefer the first name you gave us..." """)
print("""Narrator: "Choose your path" """)
start()

#End of Starting Text
# Out:
# Evil Person: "hello... Hello... HELLLLLLOOOOoooo!
# Oh good you are finally awake. Now try to escape my dungeon. If you
# escape you will find riches, fame, and my anger. My death trap is so amazing
# it should easily kill someone of your standing. Get up now what do you see."
#
# Narrator: "As you can see you are in a square room with nothing in it except 3 doors.
# There is a green door, a yellow door, and a red door. What path will you take?"
#
# Evil Person: "Umm was that you talking just now?... no? Huh I thought I got rid
# of that pesty ghost. Oh well I can just send it to the after life after I watch you die.
#
# Narrator: "...Anyways, what is your name?"
# adam
#
#
# Evil Person: "HAHAHA what a stupid name!"
#
# Narrator: "Shut up already it's better than having your name be "Evil Person"
#
# Evil Person: ...
#
# Narrator: "But he's sort of right you can pick a different name if you want to."
#
#
# Adam
#
#   Narrator: "Yeah that's a way better name good choice."
#
# ...
